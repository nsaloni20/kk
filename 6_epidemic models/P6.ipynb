# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt

# %%
# !pip install ndlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ndlib
#   Downloading ndlib-5.1.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting netdispatch (from ndlib)
#   Downloading netdispatch-0.1.0-py3-none-any.whl.metadata (744 bytes)
# Collecting python-igraph (from ndlib)
#   Downloading python_igraph-1.0.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in c:\users\kids\appdata\roaming\python\python312\site-packages (from ndlib) (2.3.5)
# Requirement already satisfied: networkx in c:\users\kids\appdata\roaming\python\python312\site-packages (from ndlib) (3.5)
# Collecting dynetx (from ndlib)
#   Downloading dynetx-0.3.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: scipy in c:\users\kids\appdata\roaming\python\python312\site-packages (from ndlib) (1.16.3)
# Collecting bokeh (from ndlib)
#   Downloading bokeh-3.8.1-py3-none-any.whl.metadata (10 kB)
# Collecting future (from ndlib)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting Jinja2>=2.9 (from bokeh->ndlib)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: contourpy>=1.2 in c:\users\kids\appdata\roaming\python\python312\site-packages (from bokeh->ndlib) (1.3.3)
# Collecting narwhals>=1.13 (from bokeh->ndlib)
#   Downloading narwhals-2.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=16.8 in c:\users\kids\appdata\roaming\python\python312\site-packages (from bokeh->ndlib) (25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\kids\appdata\roaming\python\python312\site-packages (from bokeh->ndlib) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\kids\appdata\roaming\python\python312\site-packages (from bokeh->ndlib) (12.0.0)
# Collecting PyYAML>=3.10 (from bokeh->ndlib)
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: tornado>=6.2 in c:\users\kids\appdata\roaming\python\python312\site-packages (from bokeh->ndlib) (6.5.2)
# Collecting xyzservices>=2021.09.1 (from bokeh->ndlib)
#   Downloading xyzservices-2025.10.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting tqdm (from dynetx->ndlib)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: decorator in c:\users\kids\appdata\roaming\python\python312\site-packages (from dynetx->ndlib) (5.2.1)
# Collecting igraph==1.0.0 (from python-igraph->ndlib)
#   Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl.metadata (4.5 kB)
# Collecting texttable>=1.6.2 (from igraph==1.0.0->python-igraph->ndlib)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh->ndlib)
#   Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kids\appdata\roaming\python\python312\site-packages (from pandas>=1.2->bokeh->ndlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kids\appdata\roaming\python\python312\site-packages (from pandas>=1.2->bokeh->ndlib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kids\appdata\roaming\python\python312\site-packages (from pandas>=1.2->bokeh->ndlib) (2025.2)
# Requirement already satisfied: colorama in c:\users\kids\appdata\roaming\python\python312\site-packages (from tqdm->dynetx->ndlib) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kids\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh->ndlib) (1.17.0)
# Downloading ndlib-5.1.1-py3-none-any.whl (110 kB)
# Downloading bokeh-3.8.1-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------- ----------------------------- 1.8/7.2 MB 10.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 8.9 MB/s eta 0:00:00
# Downloading dynetx-0.3.2-py3-none-any.whl (39 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading netdispatch-0.1.0-py3-none-any.whl (3.3 kB)
# Downloading python_igraph-1.0.0-py3-none-any.whl (9.2 kB)
# Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------- ----------------------- 1.3/3.2 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.2 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 4.7 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading narwhals-2.12.0-py3-none-any.whl (425 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Downloading xyzservices-2025.10.0-py3-none-any.whl (92 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, xyzservices, tqdm, PyYAML, narwhals, MarkupSafe, igraph, future, python-igraph, Jinja2, dynetx, netdispatch, bokeh, ndlib
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.3 PyYAML-6.0.3 bokeh-3.8.1 dynetx-0.3.2 future-1.0.0 igraph-1.0.0 narwhals-2.12.0 ndlib-5.1.1 netdispatch-0.1.0 python-igraph-1.0.0 texttable-1.7.0 tqdm-4.67.1 xyzservices-2025.10.0
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
from ndlib.viz.mpl.DiffusionTrend import DiffusionTrend
# Out:
# no display found. Using non-interactive Agg backend

# %%
#1 Define the network topology 
# create a random erdos-Renyi graph as an example
g = nx.erdos_renyi_graph(1000,0.1)

# %%
#  2. Define the epidermic model (eg SIR)
model = ep.SIRModel(g) #ep.SISModel(g)

# 3. configure the model parameters
cfg = mc.Configuration()
cfg.add_model_parameter('beta', 0.01) #infection rate
cfg.add_model_parameter('gamma', 0.005) #recovery rate
cfg.add_model_parameter('percentage_infected', 0.05) #inital percentage of infected nodes
model.set_initial_status(cfg)

#4. execute the simulation
iterations = model.iteration_bunch(200) #simulaed for 200 iterations
trends = model.build_trends(iterations)

# %%
# %matplotlib inline
# 5. visualize the diffusion trends
viz = DiffusionTrend(model, trends)
viz.plot(filename='sir_diffusion_trend.pdf') #save the plot to a pdf file 
plt.show()

# %%
model_sis = ep.SISModel(g)
cfg_sis = mc.Configuration()
cfg_sis.add_model_parameter("beta", 0.02)
cfg_sis.add_model_parameter("lambda", 0.01)
cfg_sis.add_model_parameter("percentage_infected", 0.05)
model_sis.set_initial_status(cfg_sis)

its_sis = model_sis.iteration_bunch(200)
tr_sis = model_sis.build_trends(its_sis)

viz_sis = DiffusionTrend(model_sis, tr_sis)
viz_sis.plot(filename="sis_diffusion_trend.pdf")
plt.show()

# %%
model_ic = ep.IndependentCascadesModel(g)

cfg_ic = mc.Configuration()
cfg_ic.add_model_initial_configuration("Infected", list(range(10)))
cfg_ic.add_model_parameter("threshold", 0.5)
cfg_ic.add_model_parameter("fraction_infected", 0.05)
model_ic.set_initial_status(cfg_ic)

its_ic = model_ic.iteration_bunch(200)
tr_ic = model_ic.build_trends(its_ic)

viz_ic = DiffusionTrend(model_ic, tr_ic)
viz_ic.plot(filename="ic_diffusion_trend.pdf")
plt.show()
